# %%
import pandas as pd
import glob
import numpy as np

# %%
#defining file path to raw data 
path = r"c:\Projects\Springboard\Capstone_I\raw_data"

#grabing all files ending in .csv
all_files = glob.glob(path + "/*.csv")
#print (all_files)

#instantiate an empty list to hold csv data
dfs = []
#run for loop to append each csv file as an entry in the list
for file in all_files:
    dfs.append(pd.read_csv(file))

# %%
#inspecting dfs[0]
print(dfs[0].info())
print(dfs[0].head())
print(dfs[0].tail())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Columns: 123 entries, # to Network ID
# dtypes: float64(36), int64(4), object(83)
# memory usage: 726.5+ KB
# None
#                                   #  <strong>Are you self-employed?</strong>  \
# 0  e49fe87572831232dcfa51b376b22039                                        0
# 1  a1eede444ac024928d247a8372d54931                                        0
# 2  37d3fd67f62bd1e0a2dea4f9cd440d98                                        0
# 3  519b759442c1cab0e9b5a8a1acb1b216                                        0
# 4  ef0af4927b575b1a3e607c11ca37870e                                        1
#
#   How many employees does your company or organization have?  \
# 0                                            100-500
# 1                                            100-500
# 2                                               6-25
# 3                                     More than 1000
# 4                                                NaN
#
#    Is your employer primarily a tech company/organization?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                1.0
# 4                                                NaN
#
#    Is your primary role within your company related to tech/IT?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                1.0
# 4                                                NaN
#
#   Does your employer provide mental health benefits as part of healthcare coverage?  \
# 0                                                 No
# 1                                                Yes
# 2                                       I don't know
# 3                                                Yes
# 4                                                NaN
#
#   Do you know the options for mental health care available under your employer-provided health coverage?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                 No
# 3                                                Yes
# 4                                                NaN
#
#   Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?  \
# 0                                                 No
# 1                                                 No
# 2                                       I don't know
# 3                                       I don't know
# 4                                                NaN
#
#   Does your employer offer resources to learn more about mental health disorders and options for seeking help?  \
# 0                                       I don't know
# 1                                                 No
# 2                                                 No
# 3                                       I don't know
# 4                                                NaN
#
#   Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?  \
# 0                                       I don't know
# 1                                       I don't know
# 2                                                Yes
# 3                                                Yes
# 4                                                NaN
#
#    ... What is your gender? What country do you <strong>live</strong> in?  \
# 0  ...               Female                                United Kingdom
# 1  ...                 male                                United Kingdom
# 2  ...                 male                      United States of America
# 3  ...                 Male                      United States of America
# 4  ...               female                      United States of America
#
#   What US state or territory do you <strong>live</strong> in?  \
# 0                                                NaN
# 1                                                NaN
# 2                                           Missouri
# 3                                         Washington
# 4                                           Illinois
#
#            What is your race? Other.3  \
# 0                         NaN     NaN
# 1                         NaN     NaN
# 2                       White     NaN
# 3                       White     NaN
# 4  More than one of the above     NaN
#
#   What country do you <strong>work</strong> in?  \
# 0                                United Kingdom
# 1                                United Kingdom
# 2                      United States of America
# 3                      United States of America
# 4                      United States of America
#
#    What US state or territory do you <strong>work</strong> in?  \
# 0                                                NaN
# 1                                                NaN
# 2                                           Missouri
# 3                                         Washington
# 4                                           Illinois
#
#       Start Date (UTC)    Submit Date (UTC)  Network ID
# 0  2018-05-16 12:32:04  2018-05-16 12:42:40  464b7a12f1
# 1  2018-05-16 12:31:13  2018-05-16 12:40:40  464b7a12f1
# 2  2018-05-09 05:34:05  2018-05-09 05:46:04  1eb7e0cb94
# 3  2018-05-04 23:19:14  2018-05-04 23:23:23  63852edbc4
# 4  2018-05-03 00:40:24  2018-05-03 00:53:20  43237889f1
#
# [5 rows x 123 columns]
#                                     #  \
# 751  97935fe0d63490dfcff17d405d06e579
# 752  2233fdfc9a4bd123359cafbfc8f53892
# 753  acff6941d3e2683957e875cc1ad4dbe6
# 754  21a68c42a608a03d541600176acc1d9a
# 755  d81c4f23936d23e056f4e63896d2b4ad
#
#      <strong>Are you self-employed?</strong>  \
# 751                                        0
# 752                                        0
# 753                                        1
# 754                                        0
# 755                                        1
#
#     How many employees does your company or organization have?  \
# 751                                             26-100
# 752                                               6-25
# 753                                                NaN
# 754                                             26-100
# 755                                                NaN
#
#      Is your employer primarily a tech company/organization?  \
# 751                                                1.0
# 752                                                1.0
# 753                                                NaN
# 754                                                1.0
# 755                                                NaN
#
#      Is your primary role within your company related to tech/IT?  \
# 751                                                1.0
# 752                                                1.0
# 753                                                NaN
# 754                                                1.0
# 755                                                NaN
#
#     Does your employer provide mental health benefits as part of healthcare coverage?  \
# 751                                       I don't know
# 752                                                Yes
# 753                                                NaN
# 754                                                Yes
# 755                                                NaN
#
#     Do you know the options for mental health care available under your employer-provided health coverage?  \
# 751                                                 No
# 752                                                 No
# 753                                                NaN
# 754                                                Yes
# 755                                                NaN
#
#     Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?  \
# 751                                                 No
# 752                                       I don't know
# 753                                                NaN
# 754                                                 No
# 755                                                NaN
#
#     Does your employer offer resources to learn more about mental health disorders and options for seeking help?  \
# 751                                       I don't know
# 752                                                 No
# 753                                                NaN
# 754                                                 No
# 755                                                NaN
#
#     Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?  \
# 751                                                Yes
# 752                                                Yes
# 753                                                NaN
# 754                                                 No
# 755                                                NaN
#
#      ... What is your gender? What country do you <strong>live</strong> in?  \
# 751  ...                 Male                                United Kingdom
# 752  ...                 Male                      United States of America
# 753  ...                  NaN                                           NaN
# 754  ...                 dude                      United States of America
# 755  ...                  NaN                                           NaN
#
#     What US state or territory do you <strong>live</strong> in?  \
# 751                                                NaN
# 752                                              Texas
# 753                                                NaN
# 754                                          Tennessee
# 755                                                NaN
#
#      What is your race? Other.3 What country do you <strong>work</strong> in?  \
# 751                 NaN     NaN                                United Kingdom
# 752               White     NaN                      United States of America
# 753                 NaN     NaN                                           NaN
# 754               White     NaN                      United States of America
# 755                 NaN     NaN                                           NaN
#
#      What US state or territory do you <strong>work</strong> in?  \
# 751                                                NaN
# 752                                              Texas
# 753                                                NaN
# 754                                          Tennessee
# 755                                                NaN
#
#         Start Date (UTC)    Submit Date (UTC)  Network ID
# 751  2017-10-19 12:44:45  2017-10-19 12:51:49  addd5ce59b
# 752  2017-09-06 13:03:08  2017-09-06 13:13:09  d345b64d29
# 753  2017-08-31 18:05:07  2017-08-31 18:06:56  bae691937c
# 754  2017-08-31 13:44:22  2017-08-31 13:55:29  d45999fdbd
# 755  2017-08-31 13:40:57  2017-08-31 13:45:48  ebd922c723
#
# [5 rows x 123 columns]

# %%
#inspecting dfs[1] 
print (dfs[1].info())
print(dfs[1].head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 417 entries, 0 to 416
# Columns: 123 entries, # to Network ID
# dtypes: float64(31), int64(9), object(83)
# memory usage: 400.8+ KB
# None
#                                   #  <strong>Are you self-employed?</strong>  \
# 0  e44a0a34f2465940beda2a1537e9b99e                                        0
# 1  0d698e3beca20fb75f19b9d528e36d73                                        0
# 2  61a40c9071eb36fa9caa254d31500c41                                        0
# 3  f8624340bead7deb08abb766704ddf6b                                        0
# 4  31d3ae93b68d79e504a0a643601b6b1e                                        0
#
#   How many employees does your company or organization have?  \
# 0                                     More than 1000
# 1                                     More than 1000
# 2                                               6-25
# 3                                               6-25
# 4                                             26-100
#
#    Is your employer primarily a tech company/organization?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                0.0
# 3                                                1.0
# 4                                                1.0
#
#    Is your primary role within your company related to tech/IT?  \
# 0                                                0.0
# 1                                                1.0
# 2                                                1.0
# 3                                                1.0
# 4                                                1.0
#
#   Does your employer provide mental health benefits as part of healthcare coverage?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                 No
# 4                                                Yes
#
#   Do you know the options for mental health care available under your employer-provided health coverage?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                 No
# 4                                                Yes
#
#   Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                Yes
#
#   Does your employer offer resources to learn more about mental health disorders and options for seeking help?  \
# 0                                                Yes
# 1                                       I don't know
# 2                                                 No
# 3                                                 No
# 4                                                Yes
#
#   Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?  \
# 0                                                Yes
# 1                                       I don't know
# 2                                       I don't know
# 3                                       I don't know
# 4                                                Yes
#
#    ... What is your gender? What country do you <strong>live</strong> in?  \
# 0  ...               Female                                        Canada
# 1  ...                 male                      United States of America
# 2  ...                 Male                      United States of America
# 3  ...                 male                                        Norway
# 4  ...      Ostensibly Male                      United States of America
#
#   What US state or territory do you <strong>live</strong> in?  \
# 0                                                NaN
# 1                                      Massachusetts
# 2                                            Florida
# 3                                                NaN
# 4                                          Tennessee
#
#    What is your race? Other.3 What country do you <strong>work</strong> in?  \
# 0                 NaN     NaN                                        Canada
# 1               White     NaN                      United States of America
# 2               White     NaN                      United States of America
# 3                 NaN     NaN                                        Norway
# 4               White     NaN                      United States of America
#
#    What US state or territory do you <strong>work</strong> in?  \
# 0                                                NaN
# 1                                      Massachusetts
# 2                                            Florida
# 3                                                NaN
# 4                                          Tennessee
#
#       Start Date (UTC)    Submit Date (UTC)  Network ID
# 0  2018-12-29 23:46:38  2018-12-30 00:00:03  4bbb884ccc
# 1  2018-12-27 21:40:40  2018-12-27 21:45:45  275e7543bd
# 2  2018-12-21 17:37:43  2018-12-21 18:08:01  43994c3dba
# 3  2018-12-21 16:37:56  2018-12-21 16:44:44  907b3a3faa
# 4  2018-12-20 19:39:02  2018-12-20 20:58:34  26df20fea3
#
# [5 rows x 123 columns]

# %%
#inspecting dfs[2]
print (dfs[2].info())
print(dfs[2].head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 27 columns):
# Timestamp                    1259 non-null object
# Age                          1259 non-null int64
# Gender                       1259 non-null object
# Country                      1259 non-null object
# state                        744 non-null object
# self_employed                1241 non-null object
# family_history               1259 non-null object
# treatment                    1259 non-null object
# work_interfere               995 non-null object
# no_employees                 1259 non-null object
# remote_work                  1259 non-null object
# tech_company                 1259 non-null object
# benefits                     1259 non-null object
# care_options                 1259 non-null object
# wellness_program             1259 non-null object
# seek_help                    1259 non-null object
# anonymity                    1259 non-null object
# leave                        1259 non-null object
# mental_health_consequence    1259 non-null object
# phys_health_consequence      1259 non-null object
# coworkers                    1259 non-null object
# supervisor                   1259 non-null object
# mental_health_interview      1259 non-null object
# phys_health_interview        1259 non-null object
# mental_vs_physical           1259 non-null object
# obs_consequence              1259 non-null object
# comments                     164 non-null object
# dtypes: int64(1), object(26)
# memory usage: 265.6+ KB
# None
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# 1          Don't know                     Maybe                      No
# 2  Somewhat difficult                        No                      No
# 3  Somewhat difficult                       Yes                     Yes
# 4          Don't know                        No                      No
#
#       coworkers supervisor mental_health_interview phys_health_interview  \
# 0  Some of them        Yes                      No                 Maybe
# 1            No         No                      No                    No
# 2           Yes        Yes                     Yes                   Yes
# 3  Some of them         No                   Maybe                 Maybe
# 4  Some of them        Yes                     Yes                   Yes
#
#   mental_vs_physical obs_consequence comments
# 0                Yes              No      NaN
# 1         Don't know              No      NaN
# 2                 No              No      NaN
# 3                 No             Yes      NaN
# 4         Don't know              No      NaN
#
# [5 rows x 27 columns]

# %%
#inspecting dfs[3]
print (dfs[3].info())
print(dfs[3].head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1433 entries, 0 to 1432
# Data columns (total 63 columns):
# Are you self-employed?                                                                                                                                                              1433 non-null int64
# How many employees does your company or organization have?                                                                                                                          1146 non-null object
# Is your employer primarily a tech company/organization?                                                                                                                             1146 non-null float64
# Is your primary role within your company related to tech/IT?                                                                                                                        263 non-null float64
# Does your employer provide mental health benefits as part of healthcare coverage?                                                                                                   1146 non-null object
# Do you know the options for mental health care available under your employer-provided coverage?                                                                                     1013 non-null object
# Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?                                              1146 non-null object
# Does your employer offer resources to learn more about mental health concerns and options for seeking help?                                                                         1146 non-null object
# Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?                                      1146 non-null object
# If a mental health issue prompted you to request a medical leave from work, asking for that leave would be:                                                                         1146 non-null object
# Do you think that discussing a mental health disorder with your employer would have negative consequences?                                                                          1146 non-null object
# Do you think that discussing a physical health issue with your employer would have negative consequences?                                                                           1146 non-null object
# Would you feel comfortable discussing a mental health disorder with your coworkers?                                                                                                 1146 non-null object
# Would you feel comfortable discussing a mental health disorder with your direct supervisor(s)?                                                                                      1146 non-null object
# Do you feel that your employer takes mental health as seriously as physical health?                                                                                                 1146 non-null object
# Have you heard of or observed negative consequences for co-workers who have been open about mental health issues in your workplace?                                                 1146 non-null object
# Do you have medical coverage (private insurance or state-provided) which includes treatment of  mental health issues?                                                               287 non-null float64
# Do you know local or online resources to seek help for a mental health disorder?                                                                                                    287 non-null object
# If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts?                                                        287 non-null object
# If you have revealed a mental health issue to a client or business contact, do you believe this has impacted you negatively?                                                        144 non-null object
# If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to coworkers or employees?                                                              287 non-null object
# If you have revealed a mental health issue to a coworker or employee, do you believe this has impacted you negatively?                                                              287 non-null object
# Do you believe your productivity is ever affected by a mental health issue?                                                                                                         287 non-null object
# If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?                                                204 non-null object
# Do you have previous employers?                                                                                                                                                     1433 non-null int64
# Have your previous employers provided mental health benefits?                                                                                                                       1264 non-null object
# Were you aware of the options for mental health care provided by your previous employers?                                                                                           1264 non-null object
# Did your previous employers ever formally discuss mental health (as part of a wellness campaign or other official communication)?                                                   1264 non-null object
# Did your previous employers provide resources to learn more about mental health issues and how to seek help?                                                                        1264 non-null object
# Was your anonymity protected if you chose to take advantage of mental health or substance abuse treatment resources with previous employers?                                        1264 non-null object
# Do you think that discussing a mental health disorder with previous employers would have negative consequences?                                                                     1264 non-null object
# Do you think that discussing a physical health issue with previous employers would have negative consequences?                                                                      1264 non-null object
# Would you have been willing to discuss a mental health issue with your previous co-workers?                                                                                         1264 non-null object
# Would you have been willing to discuss a mental health issue with your direct supervisor(s)?                                                                                        1264 non-null object
# Did you feel that your previous employers took mental health as seriously as physical health?                                                                                       1264 non-null object
# Did you hear of or observe negative consequences for co-workers with mental health issues in your previous workplaces?                                                              1264 non-null object
# Would you be willing to bring up a physical health issue with a potential employer in an interview?                                                                                 1433 non-null object
# Why or why not?                                                                                                                                                                     1095 non-null object
# Would you bring up a mental health issue with a potential employer in an interview?                                                                                                 1433 non-null object
# Why or why not?.1                                                                                                                                                                   1126 non-null object
# Do you feel that being identified as a person with a mental health issue would hurt your career?                                                                                    1433 non-null object
# Do you think that team members/co-workers would view you more negatively if they knew you suffered from a mental health issue?                                                      1433 non-null object
# How willing would you be to share with friends and family that you have a mental illness?                                                                                           1433 non-null object
# Have you observed or experienced an unsupportive or badly handled response to a mental health issue in your current or previous workplace?                                          1344 non-null object
# Have your observations of how another individual who discussed a mental health disorder made you less likely to reveal a mental health issue yourself in your current workplace?    657 non-null object
# Do you have a family history of mental illness?                                                                                                                                     1433 non-null object
# Have you had a mental health disorder in the past?                                                                                                                                  1433 non-null object
# Do you currently have a mental health disorder?                                                                                                                                     1433 non-null object
# If yes, what condition(s) have you been diagnosed with?                                                                                                                             568 non-null object
# If maybe, what condition(s) do you believe you have?                                                                                                                                322 non-null object
# Have you been diagnosed with a mental health condition by a medical professional?                                                                                                   1433 non-null object
# If so, what condition(s) were you diagnosed with?                                                                                                                                   711 non-null object
# Have you ever sought treatment for a mental health issue from a mental health professional?                                                                                         1433 non-null int64
# If you have a mental health issue, do you feel that it interferes with your work when being treated effectively?                                                                    1433 non-null object
# If you have a mental health issue, do you feel that it interferes with your work when NOT being treated effectively?                                                                1433 non-null object
# What is your age?                                                                                                                                                                   1433 non-null int64
# What is your gender?                                                                                                                                                                1430 non-null object
# What country do you live in?                                                                                                                                                        1433 non-null object
# What US state or territory do you live in?                                                                                                                                          840 non-null object
# What country do you work in?                                                                                                                                                        1433 non-null object
# What US state or territory do you work in?                                                                                                                                          851 non-null object
# Which of the following best describes your work position?                                                                                                                           1433 non-null object
# Do you work remotely?                                                                                                                                                               1433 non-null object
# dtypes: float64(3), int64(4), object(56)
# memory usage: 705.4+ KB
# None
#    Are you self-employed?  \
# 0                       0
# 1                       0
# 2                       0
# 3                       1
# 4                       0
#
#   How many employees does your company or organization have?  \
# 0                                             26-100
# 1                                               6-25
# 2                                               6-25
# 3                                                NaN
# 4                                               6-25
#
#    Is your employer primarily a tech company/organization?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                NaN
# 4                                                0.0
#
#    Is your primary role within your company related to tech/IT?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                1.0
#
#   Does your employer provide mental health benefits as part of healthcare coverage?  \
# 0                    Not eligible for coverage / N/A
# 1                                                 No
# 2                                                 No
# 3                                                NaN
# 4                                                Yes
#
#   Do you know the options for mental health care available under your employer-provided coverage?  \
# 0                                                NaN
# 1                                                Yes
# 2                                                NaN
# 3                                                NaN
# 4                                                Yes
#
#   Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?  \
# 0                                                 No
# 1                                                Yes
# 2                                                 No
# 3                                                NaN
# 4                                                 No
#
#   Does your employer offer resources to learn more about mental health concerns and options for seeking help?  \
# 0                                                 No
# 1                                                Yes
# 2                                                 No
# 3                                                NaN
# 4                                                 No
#
#   Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?  \
# 0                                       I don't know
# 1                                                Yes
# 2                                       I don't know
# 3                                                NaN
# 4                                                 No
#
#   If a mental health issue prompted you to request a medical leave from work, asking for that leave would be:  \
# 0                                          Very easy
# 1                                      Somewhat easy
# 2                         Neither easy nor difficult
# 3                                                NaN
# 4                         Neither easy nor difficult
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   If you have a mental health issue, do you feel that it interferes with your work when being treated effectively?  \
# 0                               Not applicable to me
# 1                                             Rarely
# 2                               Not applicable to me
# 3                                          Sometimes
# 4                                          Sometimes
#
#   If you have a mental health issue, do you feel that it interferes with your work when NOT being treated effectively?  \
# 0                               Not applicable to me
# 1                                          Sometimes
# 2                               Not applicable to me
# 3                                          Sometimes
# 4                                          Sometimes
#
#   What is your age? What is your gender? What country do you live in?  \
# 0                39                 Male               United Kingdom
# 1                29                 male     United States of America
# 2                38                Male                United Kingdom
# 3                43                 male               United Kingdom
# 4                43               Female     United States of America
#
#   What US state or territory do you live in?  What country do you work in?  \
# 0                                        NaN                United Kingdom
# 1                                   Illinois      United States of America
# 2                                        NaN                United Kingdom
# 3                                        NaN                United Kingdom
# 4                                   Illinois      United States of America
#
#   What US state or territory do you work in?  \
# 0                                        NaN
# 1                                   Illinois
# 2                                        NaN
# 3                                        NaN
# 4                                   Illinois
#
#   Which of the following best describes your work position?  \
# 0                                 Back-end Developer
# 1             Back-end Developer|Front-end Developer
# 2                                 Back-end Developer
# 3                               Supervisor/Team Lead
# 4  Executive Leadership|Supervisor/Team Lead|Dev ...
#
#   Do you work remotely?
# 0             Sometimes
# 1                 Never
# 2                Always
# 3             Sometimes
# 4             Sometimes
#
# [5 rows x 63 columns]

# %% [markdown]
# Noticing dfs[2] has fewer columns than the other datasets, my idea is to normalize other data sets to match.
#
# Column headings are not all straight forward, so including documentation from https://www.kaggle.com/osmi/mental-health-in-tech-survey for easier reference:
# <b>This dataset contains the following data:</b>
#
# Timestamp
#
# Age
#
# Gender
#
# Country
#
# state: If you live in the United States, which state or territory do you live in?
#
# self_employed: Are you self-employed?
#
# family_history: Do you have a family history of mental illness?
#
# treatment: Have you sought treatment for a mental health condition?
#
# work_interfere: If you have a mental health condition, do you feel that it interferes with your work?
#
# no_employees: How many employees does your company or organization have?
#
# remote_work: Do you work remotely (outside of an office) at least 50% of the time?
#
# tech_company: Is your employer primarily a tech company/organization?
#
# benefits: Does your employer provide mental health benefits?
#
# care_options: Do you know the options for mental health care your employer provides?
#
# wellness_program: Has your employer ever discussed mental health as part of an employee wellness program?
#
# seek_help: Does your employer provide resources to learn more about mental health issues and how to seek help?
#
# anonymity: Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources?
#
# leave: How easy is it for you to take medical leave for a mental health condition?
#
# mental_health_consequence: Do you think that discussing a mental health issue with your employer would have negative consequences?
#
# phys_health_consequence: Do you think that discussing a physical health issue with your employer would have negative consequences?
#
# coworkers: Would you be willing to discuss a mental health issue with your coworkers?
#
# supervisor: Would you be willing to discuss a mental health issue with your direct supervisor(s)?
#
# mental_health_interview: Would you bring up a mental health issue with a potential employer in an interview?
#
# phys_health_interview: Would you bring up a physical health issue with a potential employer in an interview?
#
# mental_vs_physical: Do you feel that your employer takes mental health as seriously as physical health?
#
# obs_consequence: Have you heard of or observed negative consequences for coworkers with mental health conditions in your workplace?
#
# comments: Any additional notes or comments

# %%
#since dfs[3] has the second least amount of cols, starting there to normalize.

#comparing cols in common
dfs[2].columns.intersection(dfs[3].columns)
# Out:
# Index([], dtype='object')

# %%
#none in common, woohoo! renaming to normalize with dfs[2]
dfs[3] = dfs[3].rename(columns={"What is your age?":"Age",
                                "What is your gender?":"Gender",
                                "What country do you live in?":"Country",
                                "What US state or territory do you live in?":"state",
                                "Are you self-employed?":"self_employed",
                                "Do you have a family history of mental illness?":"family_history",
                                "Have you ever sought treatment for a mental health issue from a mental health professional?":"treatment",
                                "Do you believe your productivity is ever affected by a mental health issue?":"work_interfere",
                                "How many employees does your company or organization have?":"no_employees",
                                "Do you work remotely?":"remote_work",
                                "Is your employer primarily a tech company/organization?":"tech_company",
                                "Does your employer provide mental health benefits as part of healthcare coverage?":"benefits",
                                "Do you know the options for mental health care available under your employer-provided coverage?":"care_options",
                                "Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?":"wellness_program",
                                "Does your employer offer resources to learn more about mental health concerns and options for seeking help?":"seek_help",
                                "Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?":"anonymity",
                                "If a mental health issue prompted you to request a medical leave from work, asking for that leave would be:":"leave",
                                "Do you think that discussing a mental health disorder with your employer would have negative consequences?":"mental_health_consequence",
                                "Do you think that discussing a physical health issue with your employer would have negative consequences?":"phys_health_consequence",
                                "Would you feel comfortable discussing a mental health disorder with your coworkers?":"coworkers",
                                "Would you feel comfortable discussing a mental health disorder with your direct supervisor(s)?":"supervisor",
                                "Would you bring up a mental health issue with a potential employer in an interview?":"mental_health_interview",
                                "Would you be willing to bring up a physical health issue with a potential employer in an interview?":"phys_health_interview",
                                "Do you feel that your employer takes mental health as seriously as physical health?":"mental_vs_physical",
                                "Have you heard of or observed negative consequences for co-workers who have been open about mental health issues in your workplace?":"obs_consequence"
                               })
#adding year col, since Timestamp is missing 
dfs[3]['year'] = 2016

# %%
#dropping dfs[2] timestamp and comments col for normalization, since these were not contained in dfs[3]
dfs[2] = dfs[2].drop(['Timestamp', 'comments'],1)
#adding year col
dfs[2]['year'] = 2014

# %%
#reassigning dfs[3] with a subset only containing cols in common with dfs[2]
dfs[3] = dfs[3][dfs[2].columns & dfs[3].columns]

# %%
#next step, lets normalize dfs[1] to match cols of dfs[2]
#listing all col names here to inspect
print(dfs[1].columns[:51])

print(dfs[1].columns[51:123])
# Out:
# Index([u'#', u'<strong>Are you self-employed?</strong>',
#        u'How many employees does your company or organization have?',
#        u'Is your employer primarily a tech company/organization?',
#        u'Is your primary role within your company related to tech/IT?',
#        u'Does your employer provide mental health benefits as part of healthcare coverage?',
#        u'Do you know the options for mental health care available under your employer-provided health coverage?',
#        u'Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?',
#        u'Does your employer offer resources to learn more about mental health disorders and options for seeking help?',
#        u'Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?',
#        u'If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?',
#        u'Would you feel more comfortable talking to your coworkers about your physical health or your mental health?',
#        u'Would you feel comfortable discussing a mental health issue with your direct supervisor(s)?',
#        u'Have you ever discussed your mental health with your employer?',
#        u'Describe the conversation you had with your employer about your mental health, including their reactions and what actions were taken to address your mental health issue/questions.',
#        u'Would you feel comfortable discussing a mental health issue with your coworkers?',
#        u'Have you ever discussed your mental health with coworkers?',
#        u'Describe the conversation with coworkers you had about your mental health including their reactions.',
#        u'Have you ever had a coworker discuss their or another coworker's mental health with you?',
#        u'Describe the conversation your coworker had with you about their mental health (please do not use names).',
#        u'Overall, how much importance does your employer place on physical health?',
#        u'Overall, how much importance does your employer place on mental health?',
#        u'Do you have medical coverage (private insurance or state-provided) that includes treatment of mental health disorders?',
#        u'Do you know local or online resources to seek help for a mental health issue?',
#        u'<strong>If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts?</strong>',
#        u'If you have revealed a mental health disorder to a client or business contact, how has this affected you or the relationship?',
#        u'<strong>If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to coworkers or employees?</strong>',
#        u'If you have revealed a mental health disorder to a coworker or employee, how has this impacted you or the relationship?',
#        u'Do you believe your productivity is ever affected by a mental health issue?',
#        u'If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?',
#        u'<strong>Do you have previous employers?</strong>',
#        u'Was your employer primarily a tech company/organization?',
#        u'<strong>Have your previous employers provided mental health benefits?</strong>',
#        u'<strong>Were you aware of the options for mental health care provided by your previous employers?</strong>',
#        u'Did your previous employers ever formally discuss mental health (as part of a wellness campaign or other official communication)?',
#        u'Did your previous employers provide resources to learn more about mental health disorders and how to seek help?',
#        u'Was your anonymity protected if you chose to take advantage of mental health or substance abuse treatment resources with previous employers?',
#        u'Would you have felt more comfortable talking to your previous employer about your physical health or your mental health?',
#        u'Would you have been willing to discuss your mental health with your direct supervisor(s)?',
#        u'Did you ever discuss your mental health with your previous employer?',
#        u'Describe the conversation you had with your previous employer about your mental health, including their reactions and actions taken to address your mental health issue/questions.',
#        u'<strong>Would you have been willing to discuss your mental health with your coworkers at previous employers?</strong>',
#        u'Did you ever discuss your mental health with a previous coworker(s)?',
#        u'Describe the conversation you had with your previous coworkers about your mental health including their reactions.',
#        u'Did you ever have a previous coworker discuss their or another coworker's mental health with you?',
#        u'Describe the conversation your coworker had with you about their mental health (please do not use names)..1',
#        u'Overall, how much importance did your previous employer place on physical health?',
#        u'Overall, how much importance did your previous employer place on mental health?',
#        u'Do you currently have a mental health disorder?',
#        u'Have you ever been diagnosed with a mental health disorder?',
#        u'Anxiety Disorder (Generalized, Social, Phobia, etc)'],
#       dtype='object')
# Index([u'Mood Disorder (Depression, Bipolar Disorder, etc)',
#        u'Psychotic Disorder (Schizophrenia, Schizoaffective, etc)',
#        u'Eating Disorder (Anorexia, Bulimia, etc)',
#        u'Attention Deficit Hyperactivity Disorder',
#        u'Personality Disorder (Borderline, Antisocial, Paranoid, etc)',
#        u'Obsessive-Compulsive Disorder', u'Post-Traumatic Stress Disorder',
#        u'Stress Response Syndromes', u'Dissociative Disorder',
#        u'Substance Use Disorder', u'Addictive Disorder', u'Other',
#        u'Anxiety Disorder (Generalized, Social, Phobia, etc).1',
#        u'Mood Disorder (Depression, Bipolar Disorder, etc).1',
#        u'Psychotic Disorder (Schizophrenia, Schizoaffective, etc).1',
#        u'Eating Disorder (Anorexia, Bulimia, etc).1',
#        u'Attention Deficit Hyperactivity Disorder.1',
#        u'Personality Disorder (Borderline, Antisocial, Paranoid, etc).1',
#        u'Obsessive-Compulsive Disorder.1', u'Post-traumatic Stress Disorder',
#        u'Stress Response Syndromes.1', u'Dissociative Disorder.1',
#        u'Substance Use Disorder.1', u'Addictive Disorder.1', u'Other.1',
#        u'Anxiety Disorder (Generalized, Social, Phobia, etc).2',
#        u'Mood Disorder (Depression, Bipolar Disorder, etc).2',
#        u'Psychotic Disorder (Schizophrenia, Schizoaffective, etc).2',
#        u'Eating Disorder (Anorexia, Bulimia, etc).2',
#        u'Attention Deficit Hyperactivity Disorder.2',
#        u'Personality Disorder (Borderline, Antisocial, Paranoid, etc).2',
#        u'Obsessive-Compulsive Disorder.2', u'Post-traumatic Stress Disorder.1',
#        u'Stress Response Syndromes.2', u'Dissociative Disorder.2',
#        u'Substance Use Disorder.2', u'Addictive Disorder.2', u'Other.2',
#        u'Have you had a mental health disorder in the past?',
#        u'Have you ever sought treatment for a mental health disorder from a mental health professional?',
#        u'Do you have a family history of mental illness?',
#        u'If you have a mental health disorder, how often do you feel that it interferes with your work <strong>when being treated effectively?</strong>',
#        u'If you have a mental health disorder, how often do you feel that it interferes with your work <strong>when</strong> <em><strong>NOT</strong></em><strong> being treated effectively (i.e., when you are experiencing symptoms)?</strong>',
#        u'Have your observations of how another individual who discussed a mental health issue made you less likely to reveal a mental health issue yourself in your current workplace?',
#        u'How willing would you be to share with friends and family that you have a mental illness?',
#        u'Would you be willing to bring up a physical health issue with a potential employer in an interview?',
#        u'Why or why not?',
#        u'Would you bring up your mental health with a potential employer in an interview?',
#        u'Why or why not?.1',
#        u'Are you openly identified at work as a person with a mental health issue?',
#        u'Has being identified as a person with a mental health issue affected your career?',
#        u'How has it affected your career?',
#        u'If they knew you suffered from a mental health disorder, how do you think that team members/co-workers would react?',
#        u'<strong>Have you observed or experienced an unsupportive or badly handled response to a mental health issue in your current or previous workplace?</strong>',
#        u'Describe the circumstances of the badly handled or unsupportive response.',
#        u'<strong>Have you observed or experienced supportive or well handled response to a mental health issue in your current or previous workplace?</strong>',
#        u'Describe the circumstances of the supportive or well handled response.',
#        u'Overall, how well do you think the tech industry supports employees with mental health issues?',
#        u'Briefly describe what you think the industry as a whole and/or employers could do to improve mental health support for employees.',
#        u'If there is anything else you would like to tell us that has not been covered by the survey questions, please use this space to do so.',
#        u'Would you be willing to talk to one of us more extensively about your experiences with mental health issues in the tech industry? (Note that all interview responses would be used <em>anonymously</em> and only with your permission.)',
#        u'What is your age?', u'What is your gender?',
#        u'What country do you <strong>live</strong> in?',
#        u'What US state or territory do you <strong>live</strong> in?',
#        u'What is your race?', u'Other.3',
#        u'What country do you <strong>work</strong> in?',
#        u'What US state or territory do you <strong>work</strong> in?',
#        u'Start Date (UTC)', u'Submit Date (UTC)', u'Network ID'],
#       dtype='object')

# %%
#renaming cols that coincide with dfs[2]
dfs[1] = dfs[1].rename(columns={"What is your age?":"Age",
                                 "What is your gender?":"Gender",
                                 "What country do you <strong>live</strong> in?":"Country",
                                 "What US state or territory do you <strong>live</strong> in?":"state",
                                 "Are you self-employed?":"self_employed",
                                 "Do you have a family history of mental illness?":"family_history",
                                 "Have you ever sought treatment for a mental health disorder from a mental health professional?":"treatment",
                                 "Do you believe your productivity is ever affected by a mental health issue?":"work_interfere",
                                 "How many employees does your company or organization have?":"no_employees",
                                 "Is your employer primarily a tech company/organization?":"tech_company",
                                 "Does your employer provide mental health benefits as part of healthcare coverage?":"benefits",
                                 "Do you know the options for mental health care available under your employer-provided health coverage?":"care_options",
                                 "Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?":"wellness_program",
                                 "Does your employer offer resources to learn more about mental health disorders and options for seeking help?":"seek_help",
                                 "Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?":"anonymity",
                                 "If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?":"leave",
                                 "Would you feel comfortable discussing a mental health issue with your coworkers?":"coworkers",
                                 "Would you feel comfortable discussing a mental health issue with your direct supervisor(s)?":"supervisor",
                                 "Would you bring up your mental health with a potential employer in an interview?":"mental_health_interview",
                                 "Would you be willing to bring up a physical health issue with a potential employer in an interview?":"phys_health_interview",
                                 "Overall, how much importance did your previous employer place on mental health?":"mental_importance",
                                 "Overall, how much importance did your previous employer place on physical health?":"physical_importance",
                                 "<strong>Have you observed or experienced an unsupportive or badly handled response to a mental health issue in your current or previous workplace?</strong>":"obs_consequence",
                                })

# %%
#adding year col
dfs[1]['year'] = 2018

# %%
#exploring mental_importance
print(dfs[1]['mental_importance'].head())
print(dfs[1]['physical_importance'].head())
# Out:
# 0    2.0
# 1    NaN
# 2    1.0
# 3    8.0
# 4    0.0
# Name: mental_importance, dtype: float64
# 0    8.0
# 1    NaN
# 2    4.0
# 3    8.0
# 4    3.0
# Name: physical_importance, dtype: float64

# %%
#since mental and physical were seperated into 1-10 scales, comparing data to fill in mental_vs_physical 

#initially setting all values to 1, meaning the persons feels that their employer takes mental health as seriously as physical
dfs[1]['mental_vs_physical'] = 1

#iterating through rows
for index, row in dfs[1].iterrows():
    x = dfs[1].loc[index]
    #if either value is NaN, set mental_vs_physical value to NaN
    if np.isnan(x['physical_importance']) or np.isnan(x['mental_importance']):
        dfs[1].loc[index, 'mental_vs_physical'] = float('nan')
    #if physical importance was rated greater than mental, infer person feels employer DOES NOT take mental health as seriously
    elif x['physical_importance'] > x['mental_importance']:
        dfs[1].loc[index, 'mental_vs_physical'] = 0

#verifying values    
print(dfs[1].loc[0:5, 'physical_importance'])
print(dfs[1].loc[0:5, 'mental_importance'])
print(dfs[1].loc[0:5, 'mental_vs_physical'])
# Out:
# 0    8.0
# 1    NaN
# 2    4.0
# 3    8.0
# 4    3.0
# 5    8.0
# Name: physical_importance, dtype: float64
# 0    2.0
# 1    NaN
# 2    1.0
# 3    8.0
# 4    0.0
# 5    8.0
# Name: mental_importance, dtype: float64
# 0    0.0
# 1    NaN
# 2    0.0
# 3    1.0
# 4    0.0
# 5    1.0
# Name: mental_vs_physical, dtype: float64

# %%
#reassigning dfs[1] with a subset only containing cols in common with dfs[2] 
#note, cols for mental_health_consequence, phys_health_consequence, amd remote_work missing from dfs[1]
dfs[1] = dfs[1][dfs[2].columns & dfs[1].columns]
dfs[1].head()
# Out:
#    Age           Gender                   Country          state  \
# 0   57           Female                    Canada            NaN
# 1   29             male  United States of America  Massachusetts
# 2   46             Male  United States of America        Florida
# 3   34             male                    Norway            NaN
# 4   29  Ostensibly Male  United States of America      Tennessee
#
#   family_history  treatment work_interfere    no_employees  tech_company  \
# 0            Yes          1            NaN  More than 1000           1.0
# 1            Yes          1            NaN  More than 1000           1.0
# 2            Yes          0            NaN            6-25           0.0
# 3             No          0            NaN            6-25           1.0
# 4            Yes          1            NaN          26-100           1.0
#
#   benefits  ...     seek_help     anonymity                       leave  \
# 0      Yes  ...           Yes           Yes          Somewhat difficult
# 1      Yes  ...  I don't know  I don't know          Somewhat difficult
# 2      Yes  ...            No  I don't know               Somewhat easy
# 3       No  ...            No  I don't know  Neither easy nor difficult
# 4      Yes  ...           Yes           Yes               Somewhat easy
#
#   coworkers supervisor mental_health_interview phys_health_interview  \
# 0        No         No                      No                    No
# 1        No         No                      No                   Yes
# 2        No         No                      No                    No
# 3     Maybe         No                      No                    No
# 4       Yes        Yes                     Yes                   Yes
#
#   mental_vs_physical  obs_consequence  year
# 0                0.0  Yes, I observed  2018
# 1                NaN               No  2018
# 2                0.0               No  2018
# 3                1.0               No  2018
# 4                0.0  Yes, I observed  2018
#
# [5 rows x 22 columns]

# %%
#finally, lets normalizeing dfs[0] to match cols of dfs[2]
#listing all col names here to inspect > noticed same q's as dfs[1], that makes it easier
print(dfs[0].columns[:51])
print(dfs[0].columns[51:123])
# Out:
# Index([u'#', u'<strong>Are you self-employed?</strong>',
#        u'How many employees does your company or organization have?',
#        u'Is your employer primarily a tech company/organization?',
#        u'Is your primary role within your company related to tech/IT?',
#        u'Does your employer provide mental health benefits as part of healthcare coverage?',
#        u'Do you know the options for mental health care available under your employer-provided health coverage?',
#        u'Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?',
#        u'Does your employer offer resources to learn more about mental health disorders and options for seeking help?',
#        u'Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?',
#        u'If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?',
#        u'Would you feel more comfortable talking to your coworkers about your physical health or your mental health?',
#        u'Would you feel comfortable discussing a mental health issue with your direct supervisor(s)?',
#        u'Have you ever discussed your mental health with your employer?',
#        u'Describe the conversation you had with your employer about your mental health, including their reactions and what actions were taken to address your mental health issue/questions.',
#        u'Would you feel comfortable discussing a mental health issue with your coworkers?',
#        u'Have you ever discussed your mental health with coworkers?',
#        u'Describe the conversation with coworkers you had about your mental health including their reactions.',
#        u'Have you ever had a coworker discuss their or another coworker's mental health with you?',
#        u'Describe the conversation your coworker had with you about their mental health (please do not use names).',
#        u'Overall, how much importance does your employer place on physical health?',
#        u'Overall, how much importance does your employer place on mental health?',
#        u'Do you have medical coverage (private insurance or state-provided) that includes treatment of mental health disorders?',
#        u'Do you know local or online resources to seek help for a mental health issue?',
#        u'<strong>If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts?</strong>',
#        u'If you have revealed a mental health disorder to a client or business contact, how has this affected you or the relationship?',
#        u'<strong>If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to coworkers or employees?</strong>',
#        u'If you have revealed a mental health disorder to a coworker or employee, how has this impacted you or the relationship?',
#        u'Do you believe your productivity is ever affected by a mental health issue?',
#        u'If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?',
#        u'<strong>Do you have previous employers?</strong>',
#        u'Was your employer primarily a tech company/organization?',
#        u'<strong>Have your previous employers provided mental health benefits?</strong>',
#        u'<strong>Were you aware of the options for mental health care provided by your previous employers?</strong>',
#        u'Did your previous employers ever formally discuss mental health (as part of a wellness campaign or other official communication)?',
#        u'Did your previous employers provide resources to learn more about mental health disorders and how to seek help?',
#        u'Was your anonymity protected if you chose to take advantage of mental health or substance abuse treatment resources with previous employers?',
#        u'Would you have felt more comfortable talking to your previous employer about your physical health or your mental health?',
#        u'Would you have been willing to discuss your mental health with your direct supervisor(s)?',
#        u'Did you ever discuss your mental health with your previous employer?',
#        u'Describe the conversation you had with your previous employer about your mental health, including their reactions and actions taken to address your mental health issue/questions.',
#        u'<strong>Would you have been willing to discuss your mental health with your coworkers at previous employers?</strong>',
#        u'Did you ever discuss your mental health with a previous coworker(s)?',
#        u'Describe the conversation you had with your previous coworkers about your mental health including their reactions.',
#        u'Did you ever have a previous coworker discuss their or another coworker's mental health with you?',
#        u'Describe the conversation your coworker had with you about their mental health (please do not use names)..1',
#        u'Overall, how much importance did your previous employer place on physical health?',
#        u'Overall, how much importance did your previous employer place on mental health?',
#        u'Do you currently have a mental health disorder?',
#        u'Have you ever been diagnosed with a mental health disorder?',
#        u'Anxiety Disorder (Generalized, Social, Phobia, etc)'],
#       dtype='object')
# Index([u'Mood Disorder (Depression, Bipolar Disorder, etc)',
#        u'Psychotic Disorder (Schizophrenia, Schizoaffective, etc)',
#        u'Eating Disorder (Anorexia, Bulimia, etc)',
#        u'Attention Deficit Hyperactivity Disorder',
#        u'Personality Disorder (Borderline, Antisocial, Paranoid, etc)',
#        u'Obsessive-Compulsive Disorder', u'Post-Traumatic Stress Disorder',
#        u'Stress Response Syndromes', u'Dissociative Disorder',
#        u'Substance Use Disorder', u'Addictive Disorder', u'Other',
#        u'Anxiety Disorder (Generalized, Social, Phobia, etc).1',
#        u'Mood Disorder (Depression, Bipolar Disorder, etc).1',
#        u'Psychotic Disorder (Schizophrenia, Schizoaffective, etc).1',
#        u'Eating Disorder (Anorexia, Bulimia, etc).1',
#        u'Attention Deficit Hyperactivity Disorder.1',
#        u'Personality Disorder (Borderline, Antisocial, Paranoid, etc).1',
#        u'Obsessive-Compulsive Disorder.1', u'Post-traumatic Stress Disorder',
#        u'Stress Response Syndromes.1', u'Dissociative Disorder.1',
#        u'Substance Use Disorder.1', u'Addictive Disorder.1', u'Other.1',
#        u'Anxiety Disorder (Generalized, Social, Phobia, etc).2',
#        u'Mood Disorder (Depression, Bipolar Disorder, etc).2',
#        u'Psychotic Disorder (Schizophrenia, Schizoaffective, etc).2',
#        u'Eating Disorder (Anorexia, Bulimia, etc).2',
#        u'Attention Deficit Hyperactivity Disorder.2',
#        u'Personality Disorder (Borderline, Antisocial, Paranoid, etc).2',
#        u'Obsessive-Compulsive Disorder.2', u'Post-traumatic Stress Disorder.1',
#        u'Stress Response Syndromes.2', u'Dissociative Disorder.2',
#        u'Substance Use Disorder.2', u'Addictive Disorder.2', u'Other.2',
#        u'Have you had a mental health disorder in the past?',
#        u'Have you ever sought treatment for a mental health disorder from a mental health professional?',
#        u'Do you have a family history of mental illness?',
#        u'If you have a mental health disorder, how often do you feel that it interferes with your work <strong>when being treated effectively?</strong>',
#        u'If you have a mental health disorder, how often do you feel that it interferes with your work <strong>when <em>NOT</em> being treated effectively (i.e., when you are experiencing symptoms)?</strong>',
#        u'Have your observations of how another individual who discussed a mental health issue made you less likely to reveal a mental health issue yourself in your current workplace?',
#        u'How willing would you be to share with friends and family that you have a mental illness?',
#        u'Would you be willing to bring up a physical health issue with a potential employer in an interview?',
#        u'Why or why not?',
#        u'Would you bring up your mental health with a potential employer in an interview?',
#        u'Why or why not?.1',
#        u'Are you openly identified at work as a person with a mental health issue?',
#        u'Has being identified as a person with a mental health issue affected your career?',
#        u'How has it affected your career?',
#        u'If they knew you suffered from a mental health disorder, how do you think that team members/co-workers would react?',
#        u'<strong>Have you observed or experienced an unsupportive or badly handled response to a mental health issue in your current or previous workplace?</strong>',
#        u'Describe the circumstances of the badly handled or unsupportive response.',
#        u'<strong>Have you observed or experienced supportive or well handled response to a mental health issue in your current or previous workplace?</strong>',
#        u'Describe the circumstances of the supportive or well handled response.',
#        u'Overall, how well do you think the tech industry supports employees with mental health issues?',
#        u'Briefly describe what you think the industry as a whole and/or employers could do to improve mental health support for employees.',
#        u'If there is anything else you would like to tell us that has not been covered by the survey questions, please use this space to do so.',
#        u'Would you be willing to talk to one of us more extensively about your experiences with mental health issues in the tech industry? (Note that all interview responses would be used <em>anonymously</em> and only with your permission.)',
#        u'What is your age?', u'What is your gender?',
#        u'What country do you <strong>live</strong> in?',
#        u'What US state or territory do you <strong>live</strong> in?',
#        u'What is your race?', u'Other.3',
#        u'What country do you <strong>work</strong> in?',
#        u'What US state or territory do you <strong>work</strong> in?',
#        u'Start Date (UTC)', u'Submit Date (UTC)', u'Network ID'],
#       dtype='object')

# %%
#renaming cols that coincide with dfs[2]
dfs[0] = dfs[0].rename(columns={"What is your age?":"Age",
                                 "What is your gender?":"Gender",
                                 "What country do you <strong>live</strong> in?":"Country",
                                 "What US state or territory do you <strong>live</strong> in?":"state",
                                 "Are you self-employed?":"self_employed",
                                 "Do you have a family history of mental illness?":"family_history",
                                 "Have you ever sought treatment for a mental health disorder from a mental health professional?":"treatment",
                                 "Do you believe your productivity is ever affected by a mental health issue?":"work_interfere",
                                 "How many employees does your company or organization have?":"no_employees",
                                 "Is your employer primarily a tech company/organization?":"tech_company",
                                 "Does your employer provide mental health benefits as part of healthcare coverage?":"benefits",
                                 "Do you know the options for mental health care available under your employer-provided health coverage?":"care_options",
                                 "Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?":"wellness_program",
                                 "Does your employer offer resources to learn more about mental health disorders and options for seeking help?":"seek_help",
                                 "Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?":"anonymity",
                                 "If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?":"leave",
                                 "Would you feel comfortable discussing a mental health issue with your coworkers?":"coworkers",
                                 "Would you feel comfortable discussing a mental health issue with your direct supervisor(s)?":"supervisor",
                                 "Would you bring up your mental health with a potential employer in an interview?":"mental_health_interview",
                                 "Would you be willing to bring up a physical health issue with a potential employer in an interview?":"phys_health_interview",
                                 "Overall, how much importance did your previous employer place on mental health?":"mental_importance",
                                 "Overall, how much importance did your previous employer place on physical health?":"physical_importance",
                                 "<strong>Have you observed or experienced an unsupportive or badly handled response to a mental health issue in your current or previous workplace?</strong>":"obs_consequence",
                                })

# %%
#adding year col
dfs[0]['year'] = 2017

# %%
#same deal as dfs[1] for mental_vs_physical 

#initially setting all values to 1, meaning the persons feels that their employer takes mental health as seriously as physical
dfs[0]['mental_vs_physical'] = 1

#iterating through rows
for index, row in dfs[0].iterrows():
    x = dfs[0].loc[index]
    #if either value is NaN, set mental_vs_physical value to NaN
    if np.isnan(x['physical_importance']) or np.isnan(x['mental_importance']):
        dfs[0].loc[index, 'mental_vs_physical'] = float('nan')
    #if physical importance was rated greater than mental, infer person feels employer DOES NOT take mental health as seriously
    elif x['physical_importance'] > x['mental_importance']:
        dfs[0].loc[index, 'mental_vs_physical'] = 0

#verifying values    
print(dfs[0].loc[0:5, 'physical_importance'])
print(dfs[0].loc[0:5, 'mental_importance'])
print(dfs[0].loc[0:5, 'mental_vs_physical'])
# Out:
# 0    3.0
# 1    5.0
# 2    8.0
# 3    NaN
# 4    8.0
# 5    7.0
# Name: physical_importance, dtype: float64
# 0    3.0
# 1    2.0
# 2    0.0
# 3    NaN
# 4    8.0
# 5    3.0
# Name: mental_importance, dtype: float64
# 0    1.0
# 1    0.0
# 2    0.0
# 3    NaN
# 4    1.0
# 5    0.0
# Name: mental_vs_physical, dtype: float64

# %%
#reassigning dfs[0] with a subset only containing cols in common with dfs[2] 

dfs[0] = dfs[0][dfs[2].columns & dfs[0].columns]
dfs[0].head()
# Out:
#     Age  Gender                   Country       state family_history  \
# 0  27.0  Female            United Kingdom         NaN             No
# 1  31.0    male            United Kingdom         NaN             No
# 2  36.0    male  United States of America    Missouri            Yes
# 3  22.0    Male  United States of America  Washington   I don't know
# 4  52.0  female  United States of America    Illinois            Yes
#
#    treatment work_interfere    no_employees  tech_company care_options  ...  \
# 0          1            NaN         100-500           1.0          Yes  ...
# 1          0            NaN         100-500           1.0          Yes  ...
# 2          1            NaN            6-25           1.0           No  ...
# 3          1            NaN  More than 1000           1.0          Yes  ...
# 4          1            Yes             NaN           NaN          NaN  ...
#
#       seek_help     anonymity         leave coworkers supervisor  \
# 0  I don't know  I don't know  I don't know       Yes        Yes
# 1            No  I don't know  I don't know       Yes      Maybe
# 2            No           Yes     Difficult     Maybe        Yes
# 3  I don't know           Yes     Difficult       Yes        Yes
# 4           NaN           NaN           NaN       NaN        NaN
#
#   mental_health_interview phys_health_interview mental_vs_physical  \
# 0                      No                   Yes                1.0
# 1                      No                   Yes                0.0
# 2                      No                 Maybe                0.0
# 3                      No                    No                NaN
# 4                      No                 Maybe                1.0
#
#       obs_consequence  year
# 0  Yes, I experienced  2017
# 1     Yes, I observed  2017
# 2  Yes, I experienced  2017
# 3      Maybe/Not sure  2017
# 4                  No  2017
#
# [5 rows x 21 columns]

# %%
#all cols match, now I need to make sure they are all numeric

for i in dfs:
    print(i.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 21 columns):
# Age                        754 non-null float64
# Gender                     743 non-null object
# Country                    754 non-null object
# state                      497 non-null object
# family_history             756 non-null object
# treatment                  756 non-null int64
# work_interfere             113 non-null object
# no_employees               643 non-null object
# tech_company               643 non-null float64
# care_options               576 non-null object
# wellness_program           643 non-null object
# seek_help                  643 non-null object
# anonymity                  643 non-null object
# leave                      643 non-null object
# coworkers                  643 non-null object
# supervisor                 643 non-null object
# mental_health_interview    756 non-null object
# phys_health_interview      756 non-null object
# mental_vs_physical         667 non-null float64
# obs_consequence            754 non-null object
# year                       756 non-null int64
# dtypes: float64(3), int64(2), object(16)
# memory usage: 124.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 417 entries, 0 to 416
# Data columns (total 22 columns):
# Age                        417 non-null int64
# Gender                     414 non-null object
# Country                    417 non-null object
# state                      311 non-null object
# family_history             417 non-null object
# treatment                  417 non-null int64
# work_interfere             56 non-null object
# no_employees               361 non-null object
# tech_company               361 non-null float64
# benefits                   361 non-null object
# care_options               324 non-null object
# wellness_program           361 non-null object
# seek_help                  361 non-null object
# anonymity                  361 non-null object
# leave                      361 non-null object
# coworkers                  361 non-null object
# supervisor                 361 non-null object
# mental_health_interview    417 non-null object
# phys_health_interview      417 non-null object
# mental_vs_physical         363 non-null float64
# obs_consequence            417 non-null object
# year                       417 non-null int64
# dtypes: float64(2), int64(3), object(17)
# memory usage: 71.7+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 26 columns):
# Age                          1259 non-null int64
# Gender                       1259 non-null object
# Country                      1259 non-null object
# state                        744 non-null object
# self_employed                1241 non-null object
# family_history               1259 non-null object
# treatment                    1259 non-null object
# work_interfere               995 non-null object
# no_employees                 1259 non-null object
# remote_work                  1259 non-null object
# tech_company                 1259 non-null object
# benefits                     1259 non-null object
# care_options                 1259 non-null object
# wellness_program             1259 non-null object
# seek_help                    1259 non-null object
# anonymity                    1259 non-null object
# leave                        1259 non-null object
# mental_health_consequence    1259 non-null object
# phys_health_consequence      1259 non-null object
# coworkers                    1259 non-null object
# supervisor                   1259 non-null object
# mental_health_interview      1259 non-null object
# phys_health_interview        1259 non-null object
# mental_vs_physical           1259 non-null object
# obs_consequence              1259 non-null object
# year                         1259 non-null int64
# dtypes: int64(2), object(24)
# memory usage: 255.8+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1433 entries, 0 to 1432
# Data columns (total 26 columns):
# Age                          1433 non-null int64
# Gender                       1430 non-null object
# Country                      1433 non-null object
# state                        840 non-null object
# self_employed                1433 non-null int64
# family_history               1433 non-null object
# treatment                    1433 non-null int64
# work_interfere               287 non-null object
# no_employees                 1146 non-null object
# remote_work                  1433 non-null object
# tech_company                 1146 non-null float64
# benefits                     1146 non-null object
# care_options                 1013 non-null object
# wellness_program             1146 non-null object
# seek_help                    1146 non-null object
# anonymity                    1146 non-null object
# leave                        1146 non-null object
# mental_health_consequence    1146 non-null object
# phys_health_consequence      1146 non-null object
# coworkers                    1146 non-null object
# supervisor                   1146 non-null object
# mental_health_interview      1433 non-null object
# phys_health_interview        1433 non-null object
# mental_vs_physical           1146 non-null object
# obs_consequence              1146 non-null object
# year                         1433 non-null int64
# dtypes: float64(1), int64(4), object(21)
# memory usage: 291.1+ KB
# None

# %%
#creating maps for later reference. 
gender_map = {0:'male', 1:'female', 2:'other'}
family_history_map = {0:'No', 1:'Yes', 2:"I don't know"}

for i in dfs:
    for index, row in i.head().iterrows():
        x = i.loc[index, 'Gender']
        if x.lower() == 'female' or x.lower() == 'f':
            i.loc[index, 'Gender'] = 1
        elif x.lower() == 'male' or x.lower() == 'M':
            i.loc[index, 'Gender'] = 0
        else:
            i.loc[index, 'Gender'] = 2
    print i.head()['Gender']
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    1
# Name: Gender, dtype: object
# 0    1
# 1    0
# 2    0
# 3    0
# 4    2
# Name: Gender, dtype: object
# 0    1
# 1    2
# 2    0
# 3    0
# 4    0
# Name: Gender, dtype: object
# 0    0
# 1    0
# 2    2
# 3    0
# 4    1
# Name: Gender, dtype: object
